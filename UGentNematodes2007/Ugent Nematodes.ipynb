# %%
import pandas as pd

# %%
data = pd.read_csv(
    'ugmd.csv',
    delimiter=',',
    dtype=object
)

# %%
data
# Out:
#      Abbrev Slide-nbr             Genus         species  \
# 0      UGMD    102755     Dorylaimoides        bulbosus
# 1      UGMD    100001      Metacrobeles      tesselatus
# 2      UGMD    100002      Metacrobeles      tesselatus
# 3      UGMD    100003      Metacrobeles      tesselatus
# 4      UGMD    100004      Metacrobeles      tesselatus
# 5      UGMD    100005      Metacrobeles      tesselatus
# 6      UGMD    100006      Metacrobeles      tesselatus
# 7      UGMD    100007      Metacrobeles      tesselatus
# 8      UGMD    100008       Chiloplacus      deconincki
# 9      UGMD    100009      Metacrobeles      tesselatus
# 10     UGMD    100010      Diplopeltula         pulchra
# 11     UGMD    100011      Diplopeltula         pulchra
# 12     UGMD    100012      Diplopeltula         pulchra
# 13     UGMD    100013      Diplopeltula       striolata
# 14     UGMD    100014      Diplopeltula           curta
# 15     UGMD    100015      Diplopeltula         nellyae
# ...

# %%
rename_columns = {"Abbrev" : "occurrenceID",
                  "datum" : "verbatimEventDate",
                  "latitude" : "decimalLatitude",
                  "longitude" : "decimalLongitude",
                  "naam" : "verbatimScientificName",
                  "oppervlakte in m²" : "organismQuantity"}
